# %% [markdown]
# # Wrangling the Data for the Narrative Visualization Project

# %% [markdown]
# By *Gilberto Ramirez <ger6@illinois.edu>*

# %% [markdown]
# ## Step 1: Wrangle Health Expenditure Data

# %% [markdown]
# *Source:* https://stats.oecd.org/
#
# *Path:* Data by theme > Health > Health expenditure and financing > Health expenditure and financing

# %%
pathname = '../data/'
filename = 'stats-oecd_health-expenditure_2022-0717.csv'

# %%
import pandas as pd

df = pd.read_csv(pathname + filename)
df.head()
# Out:
#       HF       Financing scheme     HC  \
# 0  HFTOT  All financing schemes  HCTOT
# 1  HFTOT  All financing schemes  HCTOT
# 2  HFTOT  All financing schemes  HCTOT
# 3  HFTOT  All financing schemes  HCTOT
# 4  HFTOT  All financing schemes  HCTOT
#
#                                         Function   HP   Provider MEASURE  \
# 0  Current expenditure on health (all functions)  HP1  Hospitals  PARCUR
# 1  Current expenditure on health (all functions)  HP1  Hospitals  PARCUR
# 2  Current expenditure on health (all functions)  HP1  Hospitals  PARCUR
# 3  Current expenditure on health (all functions)  HP1  Hospitals  PARCUR
# 4  Current expenditure on health (all functions)  HP1  Hospitals  PARCUR
#
#                                   Measure LOCATION    Country  ...  Year  \
# 0  Share of current expenditure on health      AUS  Australia  ...  1971
# 1  Share of current expenditure on health      AUS  Australia  ...  1972
# 2  Share of current expenditure on health      AUS  Australia  ...  1973
# 3  Share of current expenditure on health      AUS  Australia  ...  1974
# 4  Share of current expenditure on health      AUS  Australia  ...  1975
#
#    Unit Code        Unit PowerCode Code  PowerCode Reference Period Code  \
# 0         PC  Percentage              0      Units                   NaN
# 1         PC  Percentage              0      Units                   NaN
# 2         PC  Percentage              0      Units                   NaN
# 3         PC  Percentage              0      Units                   NaN
# 4         PC  Percentage              0      Units                   NaN
#
#    Reference Period   Value  Flag Codes Flags
# 0               NaN  50.933         NaN   NaN
# 1               NaN  51.398         NaN   NaN
# 2               NaN  51.396         NaN   NaN
# 3               NaN  50.159         NaN   NaN
# 4               NaN  50.705         NaN   NaN
#
# [5 rows x 21 columns]

# %%
df['Measure'].value_counts()
# Out:
# Current prices                              84982
# Per capita, current prices                  84747
# Share of current expenditure on health      84088
# Per capita, current prices, current PPPs    83167
# Share of gross domestic product             81894
# Name: Measure, dtype: int64

# %%
df = df[df['Measure'] == 'Per capita, current prices, current PPPs']

# %%
df['Measure'].value_counts()
# Out:
# Per capita, current prices, current PPPs    83167
# Name: Measure, dtype: int64

# %%
df['Provider'].value_counts()
# Out:
# All providers                                                   37075
# Providers of ambulatory health care                              7450
# Hospitals                                                        7374
# Retailers and other providers of medical goods                   5105
# Residential long-term care facilities                            4714
# Rest of the economy                                              4569
# Providers of health care system administration and financing     4449
# Providers of ancillary services                                  4262
# Providers of preventive care                                     4066
# Rest of the world                                                2925
# Providers unknown                                                1178
# Name: Provider, dtype: int64

# %%
df = df[df['Provider'] == 'All providers']

# %%
df['Provider'].value_counts()
# Out:
# All providers    37075
# Name: Provider, dtype: int64

# %%
df['Function'].value_counts()
# Out:
# Current expenditure on health (all functions)                7194
# Outpatient curative and rehabilitative care                  4762
# Medical goods (non-specified by function)                    4567
# Inpatient curative and rehabilitative care                   4357
# Preventive care                                              3829
# Ancillary services (non-specified by function)               3698
# Long-term care (health)                                      3679
# Governance and health system and financing administration    3645
# Other health care services unknown                           1344
# Name: Function, dtype: int64

# %%
df = df[df['Function'] == 'Current expenditure on health (all functions)']

# %%
df['Function'].value_counts()
# Out:
# Current expenditure on health (all functions)    7194
# Name: Function, dtype: int64

# %%
df['Financing scheme'].value_counts()
# Out:
# All financing schemes                                 1609
# Voluntary schemes/household out-of-pocket payments    1574
# Government/compulsory schemes                         1557
# Household out-of-pocket payments                      1282
# Voluntary health care payment schemes                 1172
# Name: Financing scheme, dtype: int64

# %%
df = df[df['Financing scheme'] == 'All financing schemes']

# %%
df['Financing scheme'].value_counts()
# Out:
# All financing schemes    1609
# Name: Financing scheme, dtype: int64

# %%
df[(df['Country'] == 'Netherlands') & (df['Year'] == 1972)]
# Out:
#            HF       Financing scheme     HC  \
# 165978  HFTOT  All financing schemes  HCTOT
#
#                                              Function     HP       Provider  \
# 165978  Current expenditure on health (all functions)  HPTOT  All providers
#
#        MEASURE                                   Measure LOCATION  \
# 165978  PPPPER  Per capita, current prices, current PPPs      NLD
#
#             Country  ...  Year  Unit Code       Unit PowerCode Code  \
# 165978  Netherlands  ...  1972        USD  US Dollar              0
#
#         PowerCode Reference Period Code  Reference Period    Value  \
# 165978      Units                   NaN               NaN  308.727
#
#         Flag Codes Flags
# 165978         NaN   NaN
#
# [1 rows x 21 columns]

# %%
dfHealthExpenditure = df[['Country', 'Year', 'Value']]
dfHealthExpenditure = dfHealthExpenditure.rename(columns={'Value': 'Health Expenditure'})
dfHealthExpenditure.reset_index(drop=True, inplace=True)
dfHealthExpenditure
# Out:
#        Country  Year  Health Expenditure
# 0      Ireland  1970             115.833
# 1      Ireland  1971             148.320
# 2      Ireland  1972             168.788
# 3      Ireland  1973             193.913
# 4      Ireland  1974             216.985
# ...        ...   ...                 ...
# 1604  Bulgaria  2016            1598.353
# 1605  Bulgaria  2017            1692.697
# 1606  Bulgaria  2018            1766.905
# 1607  Bulgaria  2019            1795.621
# 1608  Bulgaria  2020            2116.889
#
# [1609 rows x 3 columns]

# %% [markdown]
# ## Step 2: Wrangle Life Expectancy Data

# %% [markdown]
# *Source:* https://stats.oecd.org/
#
# *Path:* Data by theme > Health > Health Status > Life expectancy

# %%
pathname = '../data/'
filename = 'stats-oecd_life-expectancy_2022-0717.csv'

# %%
import pandas as pd

df = pd.read_csv(pathname + filename)
df.head()
# Out:
#         VAR          Variable      UNIT Measure  COU    Country   YEA  Year  \
# 0  EVIEFE00  Females at birth  EVIDUREV   Years  AUS  Australia  1970  1970
# 1  EVIEFE00  Females at birth  EVIDUREV   Years  AUS  Australia  1971  1971
# 2  EVIEFE00  Females at birth  EVIDUREV   Years  AUS  Australia  1972  1972
# 3  EVIEFE00  Females at birth  EVIDUREV   Years  AUS  Australia  1973  1973
# 4  EVIEFE00  Females at birth  EVIDUREV   Years  AUS  Australia  1974  1974
#
#    Value Flag Codes Flags
# 0   74.2        NaN   NaN
# 1   74.9        NaN   NaN
# 2   75.4        NaN   NaN
# 3   75.5        NaN   NaN
# 4   75.4        NaN   NaN

# %%
df = df[(df['Variable'] == 'Total population at birth') & (df['Measure'] == 'Years')]

# %%
df
# Out:
#             VAR                   Variable      UNIT Measure  COU    Country  \
# 510    EVIETOTA  Total population at birth  EVIDUREV   Years  AUS  Australia
# 511    EVIETOTA  Total population at birth  EVIDUREV   Years  AUS  Australia
# 512    EVIETOTA  Total population at birth  EVIDUREV   Years  AUS  Australia
# 513    EVIETOTA  Total population at birth  EVIDUREV   Years  AUS  Australia
# 514    EVIETOTA  Total population at birth  EVIDUREV   Years  AUS  Australia
# ...         ...                        ...       ...     ...  ...        ...
# 42465  EVIETOTA  Total population at birth  EVIDUREV   Years  ARG  Argentina
# 42466  EVIETOTA  Total population at birth  EVIDUREV   Years  ARG  Argentina
# 42467  EVIETOTA  Total population at birth  EVIDUREV   Years  ARG  Argentina
# 42468  EVIETOTA  Total population at birth  EVIDUREV   Years  ARG  Argentina
# 42469  EVIETOTA  Total population at birth  EVIDUREV   Years  ARG  Argentina
#
#         YEA  Year  Value Flag Codes Flags
# 510    1976  1976   72.8        NaN   NaN
# 511    1981  1981   74.8        NaN   NaN
# 512    1982  1982   74.6        NaN   NaN
# 513    1983  1983   75.4        NaN   NaN
# 514    1984  1984   75.7        NaN   NaN
# ...     ...   ...    ...        ...   ...
# 42465  2016  2016   76.2        NaN   NaN
# 42466  2017  2017   76.4        NaN   NaN
# 42467  2018  2018   76.5        NaN   NaN
# 42468  2019  2019   76.7        NaN   NaN
# 42469  2020  2020   76.8        NaN   NaN
#
# [2407 rows x 11 columns]

# %%
dfLifeExpectancy = df[['Country', 'Year', 'Value']]
dfLifeExpectancy = dfLifeExpectancy.rename(columns={'Value': 'Life Expectancy'})
dfLifeExpectancy.reset_index(drop=True, inplace=True)
dfLifeExpectancy
# Out:
#         Country  Year  Life Expectancy
# 0     Australia  1976             72.8
# 1     Australia  1981             74.8
# 2     Australia  1982             74.6
# 3     Australia  1983             75.4
# 4     Australia  1984             75.7
# ...         ...   ...              ...
# 2402  Argentina  2016             76.2
# 2403  Argentina  2017             76.4
# 2404  Argentina  2018             76.5
# 2405  Argentina  2019             76.7
# 2406  Argentina  2020             76.8
#
# [2407 rows x 3 columns]

# %% [markdown]
# ## Step 3: Combine Health Expenditure and Life Expectancy Data

# %%
df = dfHealthExpenditure.merge(dfLifeExpectancy, how='inner', on=['Country', 'Year'])
df
# Out:
#        Country  Year  Health Expenditure  Life Expectancy
# 0      Ireland  1970             115.833             71.2
# 1      Ireland  1978             342.642             71.5
# 2      Ireland  1979             395.014             72.3
# 3      Ireland  1980             475.486             72.9
# 4      Ireland  1981             491.625             72.9
# ...        ...   ...                 ...              ...
# 1539  Bulgaria  2016            1598.353             74.9
# 1540  Bulgaria  2017            1692.697             74.8
# 1541  Bulgaria  2018            1766.905             75.0
# 1542  Bulgaria  2019            1795.621             75.1
# 1543  Bulgaria  2020            2116.889             73.6
#
# [1544 rows x 4 columns]

# %% [markdown]
# ## Step 4: Wrangle GDP Per Capita Data

# %% [markdown]
# *Source:* https://stats.oecd.org/
#
# *Path:* Data by theme > National Accounts > Annual National Accounts > Main Aggregates > Gross domestic product (GDP) > GDP per head, US $, current prices, current PPPs

# %%
pathname = '../data/'
filename = 'stats-oecd_gdp-per-capita_2022-0717.csv'

# %%
import pandas as pd

dfGDPPerCapita = pd.read_csv(pathname + filename)
dfGDPPerCapita.head()
# Out:
#   LOCATION    Country TRANSACT                                    Transaction  \
# 0      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 1      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 2      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 3      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 4      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
#
#   MEASURE                                 Measure  TIME  Year Unit Code  \
# 0    HCPC  Per head, current prices, current PPPs  2015  2015       USD
# 1    HCPC  Per head, current prices, current PPPs  2016  2016       USD
# 2    HCPC  Per head, current prices, current PPPs  2017  2017       USD
# 3    HCPC  Per head, current prices, current PPPs  2018  2018       USD
# 4    HCPC  Per head, current prices, current PPPs  2019  2019       USD
#
#         Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  US Dollar               0     Units                    NaN
# 1  US Dollar               0     Units                    NaN
# 2  US Dollar               0     Units                    NaN
# 3  US Dollar               0     Units                    NaN
# 4  US Dollar               0     Units                    NaN
#
#    Reference Period         Value Flag Codes Flags
# 0               NaN  47232.629120        NaN   NaN
# 1               NaN  50150.652199        NaN   NaN
# 2               NaN  50699.175108        NaN   NaN
# 3               NaN  52980.734327        NaN   NaN
# 4               NaN  52669.473903        NaN   NaN

# %%
dfGDPPerCapita = dfGDPPerCapita[(dfGDPPerCapita['Year'] == 2021) & (dfGDPPerCapita['LOCATION'].str.len() == 3)]
dfGDPPerCapita = dfGDPPerCapita[['Country', 'Value', 'LOCATION']]
dfGDPPerCapita = dfGDPPerCapita.rename(columns={'Value': 'GDP Per Capita'})

# %%
dfGDPPerCapita = dfGDPPerCapita.sort_values(by='GDP Per Capita', ascending=False)
dfGDPPerCapita.reset_index(drop=True, inplace=True)
dfGDPPerCapita
# Out:
#             Country  GDP Per Capita LOCATION
# 0        Luxembourg   134340.373726      LUX
# 1           Ireland   106659.463928      IRL
# 2            Norway    79162.871042      NOR
# 3       Switzerland    77235.961977      CHE
# 4     United States    69558.470785      USA
# 5           Denmark    64876.683301      DNK
# 6       Netherlands    63445.083337      NLD
# 7         Australia    61631.938800      AUS
# 8            Sweden    60149.585635      SWE
# 9           Belgium    58925.223286      BEL
# 10          Austria    58338.848817      AUT
# 11          Germany    57880.471333      DEU
# 12          Iceland    57614.693442      ISL
# 13          Finland    54681.714503      FIN
# 14           Canada    52021.596768      CAN
# 15           France    50543.711372      FRA
# 16   United Kingdom    49524.925097      GBR
# 17            Malta    47386.374313      MLT
# 18            Korea    46731.416375      KOR
# 19      New Zealand    46388.713365      NZL
# 20            Italy    45902.228940      ITA
# 21   Czech Republic    44197.925718      CZE
# 22           Israel    43712.289525      ISR
# 23         Slovenia    43605.726721      SVN
# 24            Japan    43001.852891      JPN
# 25        Lithuania    42550.554521      LTU
# 26           Cyprus    42388.316420      CYP
# 27          Estonia    42185.012177      EST
# 28            Spain    40775.352596      ESP
# 29           Poland    37400.262349      POL
# 30          Hungary    36751.739602      HUN
# 31         Portugal    35914.440547      PRT
# 32          Romania    35254.361185      ROU
# 33           Latvia    34471.311790      LVA
# 34          Croatia    33826.093806      HRV
# 35  Slovak Republic    32986.812105      SVK
# 36           Greece    31281.571731      GRC
# 37          Türkiye    30796.759224      TUR
# 38         Bulgaria    26743.197880      BGR
# 39       Costa Rica    23287.453499      CRI
# 40           Mexico    20386.907843      MEX
# 41         Colombia    17341.848136      COL

# %% [markdown]
# ## Step 5: Keep Top N Richest Countries Only

# %%
N = 21  # target is 20 but Malta has no data

# %%
dfGDPPerCapita = dfGDPPerCapita.nlargest(N, 'GDP Per Capita')

# %%
dfGDPPerCapita
# Out:
#            Country  GDP Per Capita LOCATION
# 0       Luxembourg   134340.373726      LUX
# 1          Ireland   106659.463928      IRL
# 2           Norway    79162.871042      NOR
# 3      Switzerland    77235.961977      CHE
# 4    United States    69558.470785      USA
# 5          Denmark    64876.683301      DNK
# 6      Netherlands    63445.083337      NLD
# 7        Australia    61631.938800      AUS
# 8           Sweden    60149.585635      SWE
# 9          Belgium    58925.223286      BEL
# 10         Austria    58338.848817      AUT
# 11         Germany    57880.471333      DEU
# 12         Iceland    57614.693442      ISL
# 13         Finland    54681.714503      FIN
# 14          Canada    52021.596768      CAN
# 15          France    50543.711372      FRA
# 16  United Kingdom    49524.925097      GBR
# 17           Malta    47386.374313      MLT
# 18           Korea    46731.416375      KOR
# 19     New Zealand    46388.713365      NZL
# 20           Italy    45902.228940      ITA

# %%
df = df.merge(dfGDPPerCapita, how='inner', on='Country')
df
# Out:
#      Country  Year  Health Expenditure  Life Expectancy  GDP Per Capita  \
# 0    Ireland  1970             115.833             71.2   106659.463928
# 1    Ireland  1978             342.642             71.5   106659.463928
# 2    Ireland  1979             395.014             72.3   106659.463928
# 3    Ireland  1980             475.486             72.9   106659.463928
# 4    Ireland  1981             491.625             72.9   106659.463928
# ..       ...   ...                 ...              ...             ...
# 940  Iceland  2017            4111.255             82.6    57614.693442
# 941  Iceland  2018            4235.661             82.9    57614.693442
# 942  Iceland  2019            4318.269             83.2    57614.693442
# 943  Iceland  2020            4620.158             83.1    57614.693442
# 944  Iceland  2021            5096.439             83.2    57614.693442
#
#     LOCATION
# 0        IRL
# 1        IRL
# 2        IRL
# 3        IRL
# 4        IRL
# ..       ...
# 940      ISL
# 941      ISL
# 942      ISL
# 943      ISL
# 944      ISL
#
# [945 rows x 6 columns]

# %%
df['Country'].value_counts()
# Out:
# Austria           52
# Norway            52
# Sweden            52
# New Zealand       51
# United States     51
# Denmark           51
# Korea             51
# Finland           51
# Iceland           51
# Germany           51
# Switzerland       51
# Belgium           51
# Netherlands       49
# Luxembourg        45
# United Kingdom    43
# Ireland           42
# Canada            41
# Australia         41
# France            35
# Italy             34
# Name: Country, dtype: int64

# %%
df.sort_values(by=['Country', 'Year'], inplace=True)

# %%
df['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'Finland',
#        'France', 'Germany', 'Iceland', 'Ireland', 'Italy', 'Korea',
#        'Luxembourg', 'Netherlands', 'New Zealand', 'Norway', 'Sweden',
#        'Switzerland', 'United Kingdom', 'United States'], dtype=object)

# %%
df = df[df['Life Expectancy'] >= 70]

# %% [markdown]
# ## Step 6: Save Results to a CSV File

# %% [markdown]
# *Source:* https://stats.oecd.org/
#
# *Path:* Data by theme > Health > Health Status > Life expectancy

# %%
pathname = '../data/'
filename = 'stats-oecd.csv'

# %%
import pandas as pd

df.to_csv(pathname + filename, index=False)
